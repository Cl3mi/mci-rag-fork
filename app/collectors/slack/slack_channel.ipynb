# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import os
import getpass
from dotenv import load_dotenv
from slack_sdk import WebClient
from slack_sdk.errors import SlackApiError

# %%
def set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

load_dotenv()
set_env("SLACK_BOT_TOKEN")
slack_api_token= os.environ.get("SLACK_BOT_TOKEN")
# Out:
# True

# %%
# Connect to Slack
client = WebClient(token=slack_api_token)

# %%
# Read the history of a channel
def read_channel_history(channel_id: str, limit: int = 100):
    try:
        response = client.conversations_history(channel=channel_id, limit=limit)
        messages = response['messages']
        return messages
    except SlackApiError as e:
        print(f"Error fetching channel history: {e.response['error']}")
        return []

# %%
# Example usage
channel_id = "C09ASFKPH8U"

# %%
messages = read_channel_history(channel_id, limit=10)
# Display the messages
for message in messages:
    print(f"{message['user']}: {message['text']} (at {message['ts']})")
# Out:
# U09BFEEFG72: <@U09BFEEFG72> has joined the channel (at 1755344356.426549)
# U0931ATJE58: :wave: Hey team, here are 3 quick tips for the week:
# :one: Prioritize smart - Focus on the top 2-3 tasks that create the biggest impact instead of spreading too thin.
# :two: Communicate early - Share blockers or questions as soon as they come up so we can solve them together.
# :three: Recharge counts - Short breaks, a walk, or even a power nap help keep energy and creativity high.
# Let’s make it a productive week :rocket: (at 1755341934.778309)
# U0931ATJE58: Hello Team, this is the new channel of Electronic Inc. (at 1755341868.512439)
# U0931ATJE58: <@U0931ATJE58> has joined the channel (at 1755341844.550959)
